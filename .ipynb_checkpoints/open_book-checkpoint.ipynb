# %%
# !pip install selenium

# %%
from selenium import webdriver
from selenium.webdriver.common.by import By
from selenium.webdriver.common.keys import Keys
from selenium.webdriver.chrome.service import Service
import time
s=Service(r'E:\chromedriver')
driver = webdriver.Chrome(service=s)
driver.get('https://splinterlands.com')

# %%
def Click (XPATH):
    driver.find_elements(By.XPATH,XPATH)[0].click()
    
def Keys(XPATH,key):
    Email = driver.find_element(By.XPATH,XPATH)
    Email.send_keys(key)

# %%
IDs = ['ID_1','ID_2']
Password = ['Password_1','Password_2']

# %%
Count = 0 

for ID in IDs :
    
    login_1 = Click('//*[@id="log_in_button"]/button')
    time.sleep(5)
    
    ID = Keys('//*[@id="email"]',f'{ID}')
    time.sleep(1)
    
    password =Keys('//*[@id="password"]',f'{Password[Count]}')
    print('Login ID : '+str(IDs[Count]))
    Count += 1
    
    time.sleep(1)
    Login = Click('//*[@id="loginBtn"]')
    time.sleep(20)
    
    try: 
        Announcement = Click('//*[@id="dialog_container"]/div/div/div/div[1]/button')
        print( 'Click Announcement' )
        time.sleep(3)
    except:    
        print( 'Not show Announcement' )

    try: 
        Welcome = Click('//*[@id="daily_update_dialog"]/div/div/div[1]/div[2]/img')
        print( 'Click Welcome' )
        time.sleep(3)
    except:    
        print( 'Not show Welcome' )
    
    Battle =Click('//*[@id="menu_item_battle"]/a/img')
    print( 'Click Battle' )
    time.sleep(3)
    
    try: 
        Claim_Rewards = Click('//*[@id="leagues_info_content"]/div[2]/div/div/div/div[2]/button')
        print( 'Click Claim Rewards' )
        time.sleep(20)
    except:
         print('Not show Claim Rewards')

    try: 
        Claim = Click('//*[@id="claim-btn"]')
        print( 'Click Claim Button' )
        time.sleep(20)
    except:
        print('Not show Claim Button')

    try:
        countRow1 =   len(driver.find_elements(By.XPATH,'//div[@class="pack-card-container"]'))
        countRow2 =   len(driver.find_elements(By.XPATH,'//div[@class="pack-card-container flip-card"]'))
        print('Count Box ')
    except:
        print('Error pack-card-container flip-card')

    box = countRow1+countRow2
    print('Total 3 boxes '+ str(box))
    Box = 1

    while Box <= box :
        driver.find_elements(By.XPATH,'//*[@id="open_pack_dialog"]/div/div/div[1]/div/div['+str(Box)+']/div/div[1]/img')[0].click()
        print('Open Box'+str(Box))
        time.sleep(5)
        Box+=1

    Box = 1
    try: 
        Close = Click('//*[@id="btnCloseOpenPack"]/span')
    except:
         print('Not show Close')
   
    time.sleep(3)
    
    Log_Out = Click('//*[@id="log_in_text"]/a/div/div[1]/div/div/div/img[2]')
    time.sleep(3)
    LogOut = Click('//*[@id="log_in_text"]/ul/li[10]/a')
    print( 'Log Out' )
    print( '----------------------------------------------' )
    time.sleep(20)
# Out:
# Login ID : goldfish01
# Not show Announcement
# Not show Welcome
# Click Battle
# Not show Claim Rewards
# Not show Claim Button
# Count Box
# Total 3 boxes 0
# Not show Close
# Log Out
# ----------------------------------------------
# Login ID : goldfish02
# Not show Announcement
# Not show Welcome
# Click Battle
# Not show Claim Rewards
# Not show Claim Button
# Count Box
# Total 3 boxes 0
# Not show Close
# Log Out
# ----------------------------------------------
# Login ID : goldfish03
# Not show Announcement
# Not show Welcome
# Click Battle
# Not show Claim Rewards
# Not show Claim Button
# Count Box
# Total 3 boxes 0
# Not show Close
# Log Out
# ----------------------------------------------
# Login ID : goldfish04
# Not show Announcement
# Not show Welcome
# Click Battle
# Not show Claim Rewards
# Not show Claim Button
# Count Box
# Total 3 boxes 0
# Not show Close
# Log Out
# ----------------------------------------------
# Login ID : goldfish05
# Not show Announcement
# Not show Welcome
# Click Battle
# Not show Claim Rewards
# Not show Claim Button
# Count Box
# Total 3 boxes 0
# Not show Close
# Log Out
# ----------------------------------------------
# Login ID : goldfish06
# Not show Announcement
# Not show Welcome
# Click Battle
# Not show Claim Rewards
# Not show Claim Button
# Count Box
# Total 3 boxes 0
# Not show Close
# Log Out
# ----------------------------------------------
# Login ID : goldfish07
# Not show Announcement
# Not show Welcome
# Click Battle
# Not show Claim Rewards
# Not show Claim Button
# Count Box
# Total 3 boxes 0
# Not show Close
# Log Out
# ----------------------------------------------
# Login ID : goldfish08
# Not show Announcement
# Not show Welcome
# Click Battle
# Not show Claim Rewards
# Not show Claim Button
# Count Box
# Total 3 boxes 0
# Not show Close
# Log Out
# ----------------------------------------------
# Login ID : goldfish09
# Not show Announcement
# Not show Welcome
# Click Battle
# Not show Claim Rewards
# Not show Claim Button
# Count Box
# Total 3 boxes 0
# Not show Close
# Log Out
# ----------------------------------------------
# Login ID : goldfish10
# Not show Announcement
# Not show Welcome
# Click Battle
# Not show Claim Rewards
# Not show Claim Button
# Count Box
# Total 3 boxes 0
# Not show Close
# Log Out
# ----------------------------------------------
# Login ID : goldfish11
# Not show Announcement
# Not show Welcome
# Click Battle
# Not show Claim Rewards
# Not show Claim Button
# Count Box
# Total 3 boxes 0
# Not show Close
# Log Out
# ----------------------------------------------
# Login ID : goldfish12
# Not show Announcement
# Not show Welcome
# Click Battle
# Not show Claim Rewards
# Not show Claim Button
# Count Box
# Total 3 boxes 0
# Not show Close
# Log Out
# ----------------------------------------------
# Login ID : goldfish13
# Not show Announcement
# Not show Welcome
# Click Battle
# Not show Claim Rewards
# Not show Claim Button
# Count Box
# Total 3 boxes 0
# Not show Close
# Log Out
# ----------------------------------------------
# Login ID : goldfish14
# Not show Announcement
# Not show Welcome
# Click Battle
# Not show Claim Rewards
# Not show Claim Button
# Count Box
# Total 3 boxes 0
# Not show Close
# Log Out
# ----------------------------------------------
# Login ID : goldfish15
# Not show Announcement
# Not show Welcome
# Click Battle
# Not show Claim Rewards
# Not show Claim Button
# Count Box
# Total 3 boxes 0
# Not show Close
# Log Out
# ----------------------------------------------
# Login ID : goldfish16
# Not show Announcement
# Not show Welcome
# Click Battle
# Not show Claim Rewards
# Not show Claim Button
# Count Box
# Total 3 boxes 0
# Not show Close
# Log Out
# ----------------------------------------------
# Login ID : goldfish17
# Not show Announcement
# Not show Welcome
# Click Battle
# Not show Claim Rewards
# Not show Claim Button
# Count Box
# Total 3 boxes 0
# Not show Close
# Log Out
# ----------------------------------------------
# Login ID : goldfish18
# Not show Announcement
# Not show Welcome
# Click Battle
# Not show Claim Rewards
# Not show Claim Button
# Count Box
# Total 3 boxes 0
# Not show Close
# Log Out
# ----------------------------------------------
# Login ID : goldfish19
# Not show Announcement
# Not show Welcome
# Click Battle
# Not show Claim Rewards
# Click Claim Button
# Count Box
# Total 3 boxes 5
# Open Box1
# Open Box2
# Open Box3
# Open Box4
# Open Box5
# Log Out
# ----------------------------------------------
# Login ID : goldfish20
# Not show Announcement
# Not show Welcome
# Click Battle
# Not show Claim Rewards
# Click Claim Button
# Count Box
# Total 3 boxes 5
# Open Box1
# Open Box2
# Open Box3
# Open Box4
# Open Box5
# Log Out
# ----------------------------------------------
# Login ID : goldfish21
# Not show Announcement
# Not show Welcome
# Click Battle
# Not show Claim Rewards
# Click Claim Button
# Count Box
# Total 3 boxes 5
# Open Box1
# Open Box2
# Open Box3
# Open Box4
# Open Box5
# Log Out
# ----------------------------------------------
# Login ID : goldfish22
# Not show Announcement
# Not show Welcome
# Click Battle
# Not show Claim Rewards
# Click Claim Button
# Count Box
# Total 3 boxes 5
# Open Box1
# Open Box2
# Open Box3
# Open Box4
# Open Box5
# Log Out
# ----------------------------------------------
# Login ID : goldfish23
# Not show Announcement
# Not show Welcome
# Click Battle
# Not show Claim Rewards
# Click Claim Button
# Count Box
# Total 3 boxes 5
# Open Box1
# Open Box2
# Open Box3
# Open Box4
# Open Box5
# Log Out
# ----------------------------------------------
# Login ID : goldfish24
# Not show Announcement
# Not show Welcome
# Click Battle
# Not show Claim Rewards
# Click Claim Button
# Count Box
# Total 3 boxes 5
# Open Box1
# Open Box2
# Open Box3
# Open Box4
# Open Box5
# Log Out
# ----------------------------------------------
# Login ID : goldfish25
# Not show Announcement
# Not show Welcome
# Click Battle
# Not show Claim Rewards
# Click Claim Button
# Count Box
# Total 3 boxes 5
# Open Box1
# Open Box2
# Open Box3
# Open Box4
# Open Box5
# Log Out
# ----------------------------------------------
# Login ID : goldfish26
# Not show Announcement
# Not show Welcome
# Click Battle
# Not show Claim Rewards
# Click Claim Button
# Count Box
# Total 3 boxes 5
# Open Box1
# Open Box2
# Open Box3
# Open Box4
# Open Box5
# Log Out
# ----------------------------------------------
# Login ID : goldfish27
# Not show Announcement
# Not show Welcome
# Click Battle
# Not show Claim Rewards
# Click Claim Button
# Count Box
# Total 3 boxes 5
# Open Box1
# Open Box2
# Open Box3
# Open Box4
# Open Box5
# Log Out
# ----------------------------------------------
# Login ID : goldfish28
# Not show Announcement
# Not show Welcome
# Click Battle
# Not show Claim Rewards
# Click Claim Button
# Count Box
# Total 3 boxes 5
# Open Box1
# Open Box2
# Open Box3
# Open Box4
# Open Box5
# Log Out
# ----------------------------------------------
# Login ID : goldfish29
# Not show Announcement
# Not show Welcome
# Click Battle
# Not show Claim Rewards
# Click Claim Button
# Count Box
# Total 3 boxes 5
# Open Box1
# Open Box2
# Open Box3
# Open Box4
# Open Box5
# Log Out
# ----------------------------------------------
# Login ID : goldfish30
# Not show Announcement
# Not show Welcome
# Click Battle
# Not show Claim Rewards
# Click Claim Button
# Count Box
# Total 3 boxes 5
# Open Box1
# Open Box2
# Open Box3
# Open Box4
# Open Box5
# Log Out
# ----------------------------------------------
# Login ID : goldfish31
# Not show Announcement
# Not show Welcome
# Click Battle
# Not show Claim Rewards
# Click Claim Button
# Count Box
# Total 3 boxes 5
# Open Box1
# Open Box2
# Open Box3
# Open Box4
# Open Box5
# Log Out
# ----------------------------------------------
# Login ID : goldfish32
# Not show Announcement
# Not show Welcome
# Click Battle
# Not show Claim Rewards
# Click Claim Button
# Count Box
# Total 3 boxes 5
# Open Box1
# Open Box2
# Open Box3
# Open Box4
# Open Box5
# Log Out
# ----------------------------------------------
# Login ID : goldfish33
# Not show Announcement
# Not show Welcome
# Click Battle
# Not show Claim Rewards
# Click Claim Button
# Count Box
# Total 3 boxes 5
# Open Box1
# Open Box2
# Open Box3
# Open Box4
# Open Box5
# Log Out
# ----------------------------------------------
# Login ID : goldfish34
# Not show Announcement
# Not show Welcome
# Click Battle
# Not show Claim Rewards
# Click Claim Button
# Count Box
# Total 3 boxes 5
# Open Box1
# Open Box2
# Open Box3
# Open Box4
# Open Box5
# Log Out
# ----------------------------------------------
# Login ID : goldfish35
# Not show Announcement
# Not show Welcome
# Click Battle
# Not show Claim Rewards
# Click Claim Button
# Count Box
# Total 3 boxes 5
# Open Box1
# Open Box2
# Open Box3
# Open Box4
# Open Box5
# Log Out
# ----------------------------------------------
# Login ID : goldfish36
# Not show Announcement
# Not show Welcome
# Click Battle
# Not show Claim Rewards
# Click Claim Button
# Count Box
# Total 3 boxes 5
# Open Box1
# Open Box2
# Open Box3
# Open Box4
# Open Box5
# Log Out
# ----------------------------------------------
# Login ID : goldfish37
# Not show Announcement
# Not show Welcome
# Click Battle
# Not show Claim Rewards
# Click Claim Button
# Count Box
# Total 3 boxes 5
# Open Box1
# Open Box2
# Open Box3
# Open Box4
# Open Box5
# Log Out
# ----------------------------------------------
# Login ID : goldfish38
# Not show Announcement
# Not show Welcome
# Click Battle
# Not show Claim Rewards
# Click Claim Button
# Count Box
# Total 3 boxes 5
# Open Box1
# Open Box2
# Open Box3
# Open Box4
# Open Box5
# Log Out
# ----------------------------------------------
# Login ID : goldfish39
# Not show Announcement
# Not show Welcome
# Click Battle
# Not show Claim Rewards
# Click Claim Button
# Count Box
# Total 3 boxes 5
# Open Box1
# Open Box2
# Open Box3
# Open Box4
# Open Box5
# Log Out
# ----------------------------------------------
# Login ID : goldfish40
# Not show Announcement
# Not show Welcome
# Click Battle
# Not show Claim Rewards
# Click Claim Button
# Count Box
# Total 3 boxes 5
# Open Box1
# Open Box2
# Open Box3
# Open Box4
# Open Box5
# Log Out
# ----------------------------------------------
# Login ID : goldfish41
# Not show Announcement
# Not show Welcome
# Click Battle
# Not show Claim Rewards
# Click Claim Button
# Count Box
# Total 3 boxes 5
# Open Box1
# Open Box2
# Open Box3
# Open Box4
# Open Box5
# Log Out
# ----------------------------------------------
# Login ID : goldfish42
# Not show Announcement
# Not show Welcome
# Click Battle
# Not show Claim Rewards
# Click Claim Button
# Count Box
# Total 3 boxes 5
# Open Box1
# Open Box2
# Open Box3
# Open Box4
# Open Box5
# Log Out
# ----------------------------------------------
# Login ID : goldfish43
# Not show Announcement
# Not show Welcome
# Click Battle
# Not show Claim Rewards
# Click Claim Button
# Count Box
# Total 3 boxes 5
# Open Box1
# Open Box2
# Open Box3
# Open Box4
# Open Box5
# Log Out
# ----------------------------------------------
# Login ID : goldfish44
# Not show Announcement
# Not show Welcome
# Click Battle
# Not show Claim Rewards
# Click Claim Button
# Count Box
# Total 3 boxes 5
# Open Box1
# Open Box2
# Open Box3
# Open Box4
# Open Box5
# Log Out
# ----------------------------------------------
# Login ID : goldfish45
# Not show Announcement
# Not show Welcome
# Click Battle
# Not show Claim Rewards
# Click Claim Button
# Count Box
# Total 3 boxes 7
# Open Box1
# Open Box2
# Open Box3
# Open Box4
# Open Box5
# Open Box6
# Open Box7
# Log Out
# ----------------------------------------------
# Login ID : goldfish46
# Not show Announcement
# Not show Welcome
# Click Battle
# Not show Claim Rewards
# Click Claim Button
# Count Box
# Total 3 boxes 5
# Open Box1
# Open Box2
# Open Box3
# Open Box4
# Open Box5
# Log Out
# ----------------------------------------------
# Login ID : goldfish47
# Not show Announcement
# Not show Welcome
# Click Battle
# Not show Claim Rewards
# Click Claim Button
# Count Box
# Total 3 boxes 7
# Open Box1
# Open Box2
# Open Box3
# Open Box4
# Open Box5
# Open Box6
# Open Box7
# Log Out
# ----------------------------------------------
# Login ID : goldfish48
# Not show Announcement
# Not show Welcome
# Click Battle
# Not show Claim Rewards
# Click Claim Button
# Count Box
# Total 3 boxes 5
# Open Box1
# Open Box2
# Open Box3
# Open Box4
# Open Box5
# Log Out
# ----------------------------------------------
# Login ID : goldfish49
# Not show Announcement
# Not show Welcome
# Click Battle
# Not show Claim Rewards
# Click Claim Button
# Count Box
# Total 3 boxes 5
# Open Box1
# Open Box2
# Open Box3
# Open Box4
# Open Box5
# Log Out
# ----------------------------------------------
# Login ID : doublehee1
# Not show Announcement
# Not show Welcome
# Click Battle
# Not show Claim Rewards
# Click Claim Button
# Count Box
# Total 3 boxes 5
# Open Box1
# Open Box2
# Open Box3
# Open Box4
# Open Box5
# Log Out
# ----------------------------------------------
# Login ID : doublehee2
# Not show Announcement
# Not show Welcome
# Click Battle
# Not show Claim Rewards
# Not show Claim Button
# Count Box
# Total 3 boxes 0
# Not show Close
# Log Out
# ----------------------------------------------
# Login ID : doublehee3
# Not show Announcement
# Not show Welcome
# Click Battle
# Not show Claim Rewards
# Click Claim Button
# Count Box
# Total 3 boxes 5
# Open Box1
# Open Box2
# Open Box3
# Open Box4
# Open Box5
# Log Out
# ----------------------------------------------
# Login ID : doublehee4
# Not show Announcement
# Not show Welcome
# Click Battle
# Not show Claim Rewards
# Click Claim Button
# Count Box
# Total 3 boxes 5
# Open Box1
# Open Box2
# Open Box3
# Open Box4
# Open Box5
# Log Out
# ----------------------------------------------
# Login ID : doublehee5
# Not show Announcement
# Not show Welcome
# Click Battle
# Not show Claim Rewards
# Click Claim Button
# Count Box
# Total 3 boxes 5
# Open Box1
# Open Box2
# Open Box3
# Open Box4
# Open Box5
# Log Out
# ----------------------------------------------
# Login ID : doublehee6
# Not show Announcement
# Not show Welcome
# Click Battle
# Not show Claim Rewards
# Click Claim Button
# Count Box
# Total 3 boxes 5
# Open Box1
# Open Box2
# Open Box3
# Open Box4
# Open Box5
# Log Out
# ----------------------------------------------
# Login ID : doublehee7
# Not show Announcement
# Not show Welcome
# Click Battle
# Not show Claim Rewards
# Click Claim Button
# Count Box
# Total 3 boxes 5
# Open Box1
# Open Box2
# Open Box3
# Open Box4
# Open Box5
# Log Out
# ----------------------------------------------
# Login ID : doublehee8
# Not show Announcement
# Not show Welcome
# Click Battle
# Not show Claim Rewards
# Click Claim Button
# Count Box
# Total 3 boxes 5
# Open Box1
# Open Box2
# Open Box3
# Open Box4
# Open Box5
# Log Out
# ----------------------------------------------
# Login ID : doublehee9
# Not show Announcement
# Not show Welcome
# Click Battle
# Not show Claim Rewards
# Click Claim Button
# Count Box
# Total 3 boxes 5
# Open Box1
# Open Box2
# Open Box3
# Open Box4
# Open Box5
# Log Out
# ----------------------------------------------
# Login ID : doublehee10
# Not show Announcement
# Not show Welcome
# Click Battle
# Not show Claim Rewards
# Click Claim Button
# Count Box
# Total 3 boxes 7
# Open Box1
# Open Box2
# Open Box3
# Open Box4
# Open Box5
# Open Box6
# Open Box7
# Log Out
# ----------------------------------------------
# Login ID : doublehee11
# Not show Announcement
# Not show Welcome
# Click Battle
# Not show Claim Rewards
# Click Claim Button
# Count Box
# Total 3 boxes 5
# Open Box1
# Open Box2
# Open Box3
# Open Box4
# Open Box5
# Log Out
# ----------------------------------------------
# Login ID : doublehee12
# Not show Announcement
# Not show Welcome
# Click Battle
# Not show Claim Rewards
# Click Claim Button
# Count Box
# Total 3 boxes 5
# Open Box1
# Open Box2
# Open Box3
# Open Box4
# Open Box5
# Log Out
# ----------------------------------------------
# Login ID : doublehee13
# Not show Announcement
# Not show Welcome
# Click Battle
# Not show Claim Rewards
# Click Claim Button
# Count Box
# Total 3 boxes 5
# Open Box1
# Open Box2
# Open Box3
# Open Box4
# Open Box5
# Log Out
# ----------------------------------------------
# Login ID : doublehee14
# Not show Announcement
# Not show Welcome
# Click Battle
# Not show Claim Rewards
# Click Claim Button
# Count Box
# Total 3 boxes 5
# Open Box1
# Open Box2
# Open Box3
# Open Box4
# Open Box5
# Log Out
# ----------------------------------------------
# Login ID : doublehee15
# Not show Announcement
# Not show Welcome
# Click Battle
# Not show Claim Rewards
# Click Claim Button
# Count Box
# Total 3 boxes 5
# Open Box1
# Open Box2
# Open Box3
# Open Box4
# Open Box5
# Log Out
# ----------------------------------------------
# Login ID : doublehee16
# Not show Announcement
# Not show Welcome
# Click Battle
# Not show Claim Rewards
# Click Claim Button
# Count Box
# Total 3 boxes 5
# Open Box1
# Open Box2
# Open Box3
# Open Box4
# Open Box5
# Log Out
# ----------------------------------------------
# Login ID : doublehee17
# Not show Announcement
# Not show Welcome
# Click Battle
# Not show Claim Rewards
# Click Claim Button
# Count Box
# Total 3 boxes 5
# Open Box1
# Open Box2
# Open Box3
# Open Box4
# Open Box5
# Log Out
# ----------------------------------------------
# Login ID : doublehee18
# Not show Announcement
# Not show Welcome
# Click Battle
# Not show Claim Rewards
# Click Claim Button
# Count Box
# Total 3 boxes 5
# Open Box1
# Open Box2
# Open Box3
# Open Box4
# Open Box5
# Log Out
# ----------------------------------------------
# Login ID : doublehee19
# Not show Announcement
# Not show Welcome
# Click Battle
# Not show Claim Rewards
# Click Claim Button
# Count Box
# Total 3 boxes 5
# Open Box1
# Open Box2
# Open Box3
# Open Box4
# Open Box5
# Log Out
# ----------------------------------------------
# Login ID : doublehee20
# Not show Announcement
# Not show Welcome
# Click Battle
# Not show Claim Rewards
# Click Claim Button
# Count Box
# Total 3 boxes 5
# Open Box1
# Open Box2
# Open Box3
# Open Box4
# Open Box5
# Log Out
# ----------------------------------------------
# Login ID : megaponyz
# Not show Announcement
# Not show Welcome
# Click Battle
# Not show Claim Rewards
# Click Claim Button
# Count Box
# Total 3 boxes 5
# Open Box1
# Open Box2
# Open Box3
# Open Box4
# Open Box5
# Log Out
# ----------------------------------------------
# Login ID : megaponyzii
# Not show Announcement
# Not show Welcome
# Click Battle
# Not show Claim Rewards
# Click Claim Button
# Count Box
# Total 3 boxes 5
# Open Box1
# Open Box2
# Open Box3
# Open Box4
# Open Box5
# Log Out
# ----------------------------------------------
# Login ID : megaponyziii
# Not show Announcement
# Not show Welcome
# Click Battle
# Not show Claim Rewards
# Click Claim Button
# Count Box
# Total 3 boxes 5
# Open Box1
# Open Box2
# Open Box3
# Open Box4
# Open Box5
# Log Out
# ----------------------------------------------
# Login ID : megaponyziv
# Not show Announcement
# Not show Welcome
# Click Battle
# Not show Claim Rewards
# Click Claim Button
# Count Box
# Total 3 boxes 5
# Open Box1
# Open Box2
# Open Box3
# Open Box4
# Open Box5
# Log Out
# ----------------------------------------------
# Login ID : megaponyzv
# Not show Announcement
# Not show Welcome
# Click Battle
# Not show Claim Rewards
# Click Claim Button
# Count Box
# Total 3 boxes 5
# Open Box1
# Open Box2
# Open Box3
# Open Box4
# Open Box5
# Log Out
# ----------------------------------------------
# Login ID : megaponyzvi
# Not show Announcement
# Not show Welcome
# Click Battle
# Not show Claim Rewards
# Click Claim Button
# Count Box
# Total 3 boxes 5
# Open Box1
# Open Box2
# Open Box3
# Open Box4
# Open Box5
# Log Out
# ----------------------------------------------
# Login ID : megaponyzvii
# Not show Announcement
# Not show Welcome
# Click Battle
# Not show Claim Rewards
# Click Claim Button
# Count Box
# Total 3 boxes 5
# Open Box1
# Open Box2
# Open Box3
# Open Box4
# Open Box5
# Log Out
# ----------------------------------------------
# Login ID : megaponyzviii
# Not show Announcement
# Not show Welcome
# Click Battle
# Not show Claim Rewards
# Click Claim Button
# Count Box
# Total 3 boxes 5
# Open Box1
# Open Box2
# Open Box3
# Open Box4
# Open Box5
# Log Out
# ----------------------------------------------
# Login ID : megaponyzix
# Not show Announcement
# Not show Welcome
# Click Battle
# Not show Claim Rewards
# Click Claim Button
# Count Box
# Total 3 boxes 5
# Open Box1
# Open Box2
# Open Box3
# Open Box4
# Open Box5
# Log Out
# ----------------------------------------------
# Login ID : megaponyzx
# Not show Announcement
# Not show Welcome
# Click Battle
# Not show Claim Rewards
# Click Claim Button
# Count Box
# Total 3 boxes 5
# Open Box1
# Open Box2
# Open Box3
# Open Box4
# Open Box5
# Log Out
# ----------------------------------------------
# Login ID : bluecat09
# Not show Announcement
# Not show Welcome
# Click Battle
# Not show Claim Rewards
# Click Claim Button
# Count Box
# Total 3 boxes 5
# Open Box1
# Open Box2
# Open Box3
# Open Box4
# Open Box5
# Log Out
# ----------------------------------------------
# Login ID : bluecat10
# Not show Announcement
# Not show Welcome
# Click Battle
# Not show Claim Rewards
# Click Claim Button
# Count Box
# Total 3 boxes 5
# Open Box1
# Open Box2
# Open Box3
# Open Box4
# Open Box5
# Log Out
# ----------------------------------------------
# Login ID : bluecat11
# Not show Announcement
# Not show Welcome
# Click Battle
# Not show Claim Rewards
# Click Claim Button
# Count Box
# Total 3 boxes 7
# Open Box1
# Open Box2
# Open Box3
# Open Box4
# Open Box5
# Open Box6
# Open Box7
# Log Out
# ----------------------------------------------
# Login ID : bluecat12
# Not show Announcement
# Not show Welcome
# Click Battle
# Not show Claim Rewards
# Click Claim Button
# Count Box
# Total 3 boxes 5
# Open Box1
# Open Box2
# Open Box3
# Open Box4
# Open Box5
# Log Out
# ----------------------------------------------
# Login ID : bluecat13
# Not show Announcement
# Not show Welcome
# Click Battle
# Not show Claim Rewards
# Click Claim Button
# Count Box
# Total 3 boxes 5
# Open Box1
# Open Box2
# Open Box3
# Open Box4
# Open Box5
# Log Out
# ----------------------------------------------
# Login ID : bluecat14
# Not show Announcement
# Not show Welcome
# Click Battle
# Not show Claim Rewards
# Click Claim Button
# Count Box
# Total 3 boxes 5
# Open Box1
# Open Box2
# Open Box3
# Open Box4
# Open Box5
# Log Out
# ----------------------------------------------
# Login ID : bluecat15
# Not show Announcement
# Not show Welcome
# Click Battle
# Not show Claim Rewards
# Click Claim Button
# Count Box
# Total 3 boxes 5
# Open Box1
# Open Box2
# Open Box3
# Open Box4
# Open Box5
# Log Out
# ----------------------------------------------
# Login ID : bluecat16
# Not show Announcement
# Not show Welcome
# Click Battle
# Not show Claim Rewards
# Click Claim Button
# Count Box
# Total 3 boxes 5
# Open Box1
# Open Box2
# Open Box3
# Open Box4
# Open Box5
# Log Out
# ----------------------------------------------
# Login ID : bluecat17
# Not show Announcement
# Not show Welcome
# Click Battle
# Not show Claim Rewards
# Click Claim Button
# Count Box
# Total 3 boxes 5
# Open Box1
# Open Box2
# Open Box3
# Open Box4
# Open Box5
# Log Out
# ----------------------------------------------
# Login ID : bluecat18
# Not show Announcement
# Not show Welcome
# Click Battle
# Not show Claim Rewards
# Not show Claim Button
# Count Box
# Total 3 boxes 0
# Not show Close
# Log Out
# ----------------------------------------------
# Login ID : bluecat20
# Not show Announcement
# Not show Welcome
# Click Battle
# Not show Claim Rewards
# Click Claim Button
# Count Box
# Total 3 boxes 5
# Open Box1
# Open Box2
# Open Box3
# Open Box4
# Open Box5
# Log Out
# ----------------------------------------------
# Login ID : bluecat21
# Not show Announcement
# Not show Welcome
# Click Battle
# Not show Claim Rewards
# Click Claim Button
# Count Box
# Total 3 boxes 5
# Open Box1
# Open Box2
# Open Box3
# Open Box4
# Open Box5
# Log Out
# ----------------------------------------------
# Login ID : bluecat22
# Not show Announcement
# Not show Welcome
# Click Battle
# Not show Claim Rewards
# Click Claim Button
# Count Box
# Total 3 boxes 5
# Open Box1
# Open Box2
# Open Box3
# Open Box4
# Open Box5
# Log Out
# ----------------------------------------------
# Login ID : bluecat23
# Not show Announcement
# Not show Welcome
# Click Battle
# Not show Claim Rewards
# Click Claim Button
# Count Box
# Total 3 boxes 5
# Open Box1
# Open Box2
# Open Box3
# Open Box4
# Open Box5
# Log Out
# ----------------------------------------------
# Login ID : bluecat24
# Not show Announcement
# Not show Welcome
# Click Battle
# Not show Claim Rewards
# Click Claim Button
# Count Box
# Total 3 boxes 5
# Open Box1
# Open Box2
# Open Box3
# Open Box4
# Open Box5
# Log Out
# ----------------------------------------------
# Login ID : bluecat25
# Not show Announcement
# Not show Welcome
# Click Battle
# Not show Claim Rewards
# Click Claim Button
# Count Box
# Total 3 boxes 5
# Open Box1
# Open Box2
# Open Box3
# Open Box4
# Open Box5
# Log Out
# ----------------------------------------------
# Login ID : bluecat26
# Not show Announcement
# Not show Welcome
# Click Battle
# Not show Claim Rewards
# Click Claim Button
# Count Box
# Total 3 boxes 5
# Open Box1
# Open Box2
# Open Box3
# Open Box4
# Open Box5
# Log Out
# ----------------------------------------------
# Login ID : bkuecat27
# Not show Announcement
# Not show Welcome
# Click Battle
# Not show Claim Rewards
# Click Claim Button
# Count Box
# Total 3 boxes 5
# Open Box1
# Open Box2
# Open Box3
# Open Box4
# Open Box5
# Log Out
# ----------------------------------------------
# Login ID : redcat11
# Not show Announcement
# Not show Welcome
# Click Battle
# Not show Claim Rewards
# Click Claim Button
# Count Box
# Total 3 boxes 5
# Open Box1
# Open Box2
# Open Box3
# Open Box4
# Open Box5
# Log Out
# ----------------------------------------------
# Login ID : redcat12
# Not show Announcement
# Not show Welcome
# Click Battle
# Not show Claim Rewards
# Click Claim Button
# Count Box
# Total 3 boxes 5
# Open Box1
# Open Box2
# Open Box3
# Open Box4
# Open Box5
# Log Out
# ----------------------------------------------
# Login ID : redcat13
# Not show Announcement
# Not show Welcome
# Click Battle
# Not show Claim Rewards
# Click Claim Button
# Count Box
# Total 3 boxes 5
# Open Box1
# Open Box2
# Open Box3
# Open Box4
# Open Box5
# Log Out
# ----------------------------------------------
# Login ID : redcat14
# Not show Announcement
# Not show Welcome
# Click Battle
# Not show Claim Rewards
# Click Claim Button
# Count Box
# Total 3 boxes 5
# Open Box1
# Open Box2
# Open Box3
# Open Box4
# Open Box5
# Log Out
# ----------------------------------------------
# Login ID : redcat15
# Not show Announcement
# Not show Welcome
# Click Battle
# Not show Claim Rewards
# Click Claim Button
# Count Box
# Total 3 boxes 5
# Open Box1
# Open Box2
# Open Box3
# Open Box4
# Open Box5
# Log Out
# ----------------------------------------------
# Login ID : redcat16
# Not show Announcement
# Not show Welcome
# Click Battle
# Not show Claim Rewards
# Click Claim Button
# Count Box
# Total 3 boxes 5
# Open Box1
# Open Box2
# Open Box3
# Open Box4
# Open Box5
# Log Out
# ----------------------------------------------
# Login ID : redcat17
